# %% [markdown]
# # <center> Projet : Moteur de recommandation d'offres d'emploi </center>
#
#
#
# <img src="https://marne.fr/sites/default/files/styles/pleine_page_article/public/marne_rsa_solidarite_active.jpg?itok=WXYTjvkx" width=492>
#
#
# ### <center>Thème : travail ,moteur de recommandation ,job matching </center>

# %% [markdown]
# # Problématique

# %% [markdown]
# L'idée  est de construire un algorithme qui permet de matcher des chercheurs d'emploi avec des offres d'entreprise. Ainsi, nous diviserons notre notebook en trois parties :
#
# * [1/ Analyse exploratoire](#partie1)
#
#
# Dans cette partie nous téléchargerons, nettoierons et analyserons notre base de données.
#
#
# * [2/ Modélisation](#partie2)
#
#
# Ensuite, nous modéliserons notre algorithme de matching étape par étape..
#
#
# * [3/ Résultats](#partie3)
#
# Enfin, nous discuterons des résultats et des limites de notre modélisation.

# %% [markdown]
# # <center> Analyse exploratoire </center>

# %% [markdown]
# # Chargement des bases

# %% [markdown]
# ### df_jobs

# %%
#Data management/data viz
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go


#Modelisation
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.metrics.pairwise import linear_kernel, cosine_similarity


#Texte
import nltk
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
import re

# Autres
import os
import random
random.seed(10)
try : 
    os.chdir(os.getcwd()+"/Data")
except :
    pass

import time




start = time.time()

# %%
pip freeze > requirements.txt
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
def tokenizer_fct(sentence) :
    # print(sentence)
    sentence_clean = sentence.replace('-', ' ').replace('+', ' ').replace('/', ' ').replace('#', ' ')
    word_tokens = word_tokenize(sentence_clean)
    return word_tokens

stop_w = list(set(stopwords.words('english'))) + ['[', ']', ',', '.', ':', '?', '(', ')']

def stop_word_filter_fct(list_words) :
    filtered_w = [w for w in list_words if not w in stop_w]
    filtered_w2 = [w for w in filtered_w if len(w) > 2]
    return filtered_w2

# En minuscule
def lower_start_fct(list_words) :
    lw = [w.lower() for w in list_words]
    return lw

def lemma_fct(list_words) :
    lemmatizer = WordNetLemmatizer()
    lem_w = [lemmatizer.lemmatize(w) for w in list_words]
    return lem_w


CLEANR = re.compile('<.*?>') 

def cleanhtml(raw_html):
  cleantext = re.sub(CLEANR, '', raw_html)
  return cleantext

def nettoyage_texte(sentence):
    return ' '.join(lemma_fct(lower_start_fct(stop_word_filter_fct(tokenizer_fct(cleanhtml(sentence))))))

# %%
df_jobs=pd.read_csv("jobs.csv")
print(df_jobs.shape)
df_jobs.head()
# Out:
# (4291, 11)
#    JobID                           Title  \
# 0     75        Administrative Assistant
# 1    505                        LAB TECH
# 2    764           Travel-Seasonal Staff
# 3    766  MARKETING/ Social Media intern
# 4    781                  Printing Sales
#
#                                          Description  \
# 0  The Administrative Assistant must be reliable ...
# 1  S. Florida Medical Device Co. seeks QC Lab Tec...
# 2  <p>Travel-Seasonal Staff </p> <p> CB331736 Ros...
# 3  <p>Marketing Rep </p> <p> CB326227 Chicago </p...
# 4  <p>Printing Sales Experienced, outside sales w...
#
#                                         Requirements           City State  \
# 0  Please refer to the Job Description to view th...        Houston    TX
# 1  General knowledge of scientific or clinical la...     Plantation    FL
# 2  Please refer to the Job Description to view th...    Des Plaines    IL
# 3  Please refer to the Job Description to view th...        Chicago    IL
# 4  Please refer to the Job Description to view th...  Schiller Park    IL
#
#   Country     Zip5                StartDate              EndDate  \
# 0      US  77036.0  2012-03-30 01:23:57.737  2012-04-29 23:59:59
# 1      US  33313.0  2012-03-23 04:48:17.063  2012-04-22 23:59:59
# 2      US  60018.0  2012-03-18 05:19:04.863  2012-04-17 23:59:59
# 3      US  60606.0   2012-03-22 10:33:46.89  2012-04-21 23:59:59
# 4      US  60176.0  2012-04-01 01:16:40.797  2012-04-30 23:59:59
#
#    JobCategoryID
# 0             20
# 1            137
# 2             59
# 3            141
# 4              4

# %%
df_jobs["Title"]=df_jobs["Title"].apply(lambda x: nettoyage_texte(x))

# %% [markdown]
# df_jobs est une base de données qui réprésentent 4291 annonces d'emplois modélisés en 11 caractéristiques. Les colonnes Title et Description ne sont pas propres (balise html, majuscule/miniscule)

# %%
print(len(df_jobs.State.unique()))
print(len(df_jobs.JobCategoryID.unique()))
# Out:
# 37
# 195

# %% [markdown]
# Les offres d'emploi sont répartis en 37 états et en 195 catégories.

# %%
df_jobs.Requirements
df_jobs.Requirements= df_jobs.Requirements.fillna('')

# %%
test=df_jobs[df_jobs.Requirements.str.contains("junior")]
list(test.Requirements[:1])
len(test)
# Out:
# 5

# %%
test=df_jobs[df_jobs.Requirements.str.contains("junior")]

# %% [markdown]
# ### df_feedbacks

# %%
df_feedbacks=pd.read_csv("feedbacks.csv")
print(df_feedbacks.shape)
df_feedbacks.head()
# Out:
# (28928, 3)
#    UserID    JobID   Event
# 0     698  1053272  viewed
# 1     698   535105  viewed
# 2     698   171400  viewed
# 3     698   804823  viewed
# 4     698  1113149  viewed

# %% [markdown]
# df_feedbacks est une base qui contient des retours des utilisateurs sur certaines des offres d'emploi.

# %%
df_feedbacks.Event.value_counts()
# Out:
# viewed     18620
# applied     9395
# hired        913
# Name: Event, dtype: int64

# %% [markdown]
# Logiquement plus les actions sont engageantes moins elles sont fréquentes.

# %%
df_feedbacks.UserID.value_counts().describe()
# Out:
# count    1861.000000
# mean       15.544331
# std        21.158714
# min         6.000000
# 25%         7.000000
# 50%        10.000000
# 75%        15.000000
# max       484.000000
# Name: UserID, dtype: float64

# %% [markdown]
# En moyenne les individus donnent 15 feedbacks et au minimum 6 et au maximum  484.

# %% [markdown]
# Le fait qu'un individu postule ou est engagé à une offre d'emploi  implique qu'il est intéressé. Si il regarde l'annonce et qu'il ne postule, c'est qu'in fine l'offre ne lui convient pas.Donc on peut créer une variable dichotomisé qui est égale à 1 si l'individu engage une action après avoir vu l'annonce sinon la variable sera égale à 0.

# %%
df_feedbacks["interet"]=0

# %%
df_feedbacks["interet"] = df_feedbacks['Event'].apply(lambda x: 1 if x in ["hired","applied"] else 0)
df_feedbacks.interet.value_counts()
# Out:
# 0    18620
# 1    10308
# Name: interet, dtype: int64

# %%
df_feedbacks.JobID.value_counts().describe()
# Out:
# count    3149.000000
# mean        9.186408
# std        16.501161
# min         2.000000
# 25%         3.000000
# 50%         4.000000
# 75%         8.000000
# max       217.000000
# Name: JobID, dtype: float64

# %% [markdown]
# 75% des offres sont vus plus de 8 fois.

# %%
popular_job=df_feedbacks.JobID.value_counts().to_frame()
liste_popular_job=list(popular_job[popular_job["JobID"]>8].index)

# %%
df_feedbacks[["UserID","JobID","interet"]]
# Out:
#         UserID    JobID  interet
# 0          698  1053272        0
# 1          698   535105        0
# 2          698   171400        0
# 3          698   804823        0
# 4          698  1113149        0
# ...        ...      ...      ...
# 28923  1468470   149425        0
# 28924  1468879   164268        0
# 28925  1469784   777461        0
# 28926  1470394   339499        0
# 28927  1472022   739020        0
#
# [28928 rows x 3 columns]

# %% [markdown]
# ### df_users

# %%
df_users=pd.read_csv("users.csv")
print(df_users.shape)
df_users.head()
# Out:
# (2337, 14)
#    UserID            City State Country ZipCode   DegreeType  \
# 0      23  Mount Prospect    IL      US   60056  High School
# 1     698          Normal    IL      US   61761         None
# 2    2305     Lake Forest    IL      US   60045         None
# 3    2785         Chicago    IL      US   60607   Bachelor's
# 4    3406          Joliet    IL      US   60435   Bachelor's
#
#                    Major       GraduationDate  WorkHistoryCount  \
# 0         Not Applicable  2002-01-01 00:00:00                 3
# 1                    NaN                  NaN                 4
# 2              insurance  2010-12-01 00:00:00                 4
# 3  International Affairs  2005-01-01 00:00:00                 6
# 4                English                  NaN                 3
#
#    TotalYearsExperience CurrentlyEmployed ManagedOthers  ManagedHowMany  \
# 0                  10.0               Yes            No               0
# 1                   7.0               Yes            No               0
# 2                   9.0               Yes            No               0
# 3                  10.0               Yes            No               0
# 4                  20.0                No           Yes             350
#
#    MajorCategoryID
# 0              0.0
# 1              NaN
# 2            180.0
# 3            191.0
# 4             40.0

# %% [markdown]
# df_users est la base qui contient les chercheurs d'emploi. On en a 2337 modélisé en 14 caractéristiques.

# %%
print(df_users.WorkHistoryCount.value_counts().sort_index())
print(77/2337)
# Out:
# 0      77
# 1     112
# 2     219
# 3     438
# 4     483
# 5     351
# 6     272
# 7     133
# 8      92
# 9      66
# 10     91
# 11      1
# 12      1
# 13      1
# Name: WorkHistoryCount, dtype: int64
# 0.0329482242190843

# %% [markdown]
# On remarque que l'on a 77 individus sans expériences. Soit 3% de nos individus.

# %%
df_users.ZipCode.value_counts().sort_index()
# Out:
# 60001     1
# 60002     3
# 60004    11
# 60005     6
# 60006     1
#          ..
# 62868     1
# 62901     1
# 62927     1
# 62948     1
# 62959     2
# Name: ZipCode, Length: 449, dtype: int64

# %% [markdown]
# ### df_users_history

# %%
df_users_history=pd.read_csv("users_history.csv")
print(df_users_history.shape)
df_users_history.head()
# Out:
# (11012, 4)
#    UserID  Sequence                                          JobTitle  \
# 0      23         1                                           Manager
# 1      23         2                               Assisting customers
# 2     698         1                                  Advocate Bromenn
# 3     698         2  Customer Service, Patient contact, drawing blood
# 4     698         3              Customer Service, Suggestive selling
#
#    JobCategoryID
# 0            0.0
# 1           30.0
# 2           88.0
# 3          135.0
# 4            1.0

# %%
df_users_history["CV_JobTitle"]=df_users_history.groupby('UserID').transform(lambda JobTitle : ' '.join(JobTitle))
df_users_history
# Out:
#         UserID  Sequence                                          JobTitle  \
# 0           23         1                                           Manager
# 1           23         2                               Assisting customers
# 2          698         1                                  Advocate Bromenn
# 3          698         2  Customer Service, Patient contact, drawing blood
# 4          698         3              Customer Service, Suggestive selling
# ...        ...       ...                                               ...
# 11007  1471500         3                                   Cocktail Server
# 11008  1471500         4     ICS Associate /Overnight Stock/Truck Unloader
# 11009  1471500         5                                   Cocktail Server
# 11010  1471500         6                                            Server
# 11011  1471500         7                                            Server
#
#        JobCategoryID                                        CV_JobTitle
# 0                0.0                        Manager Assisting customers
# 1               30.0                        Manager Assisting customers
# 2               88.0  Advocate Bromenn Customer Service, Patient con...
# 3              135.0  Advocate Bromenn Customer Service, Patient con...
# 4                1.0  Advocate Bromenn Customer Service, Patient con...
# ...              ...                                                ...
# 11007           91.0  Stocker Cocktail Server ICS Associate /Overnig...
# 11008          136.0  Stocker Cocktail Server ICS Associate /Overnig...
# 11009           91.0  Stocker Cocktail Server ICS Associate /Overnig...
# 11010           91.0  Stocker Cocktail Server ICS Associate /Overnig...
# 11011           91.0  Stocker Cocktail Server ICS Associate /Overnig...
#
# [11012 rows x 5 columns]

# %%
df_users_history['JobCategoryID'] = df_users_history['JobCategoryID'].astype(int)
df_users_history
# Out:
#         UserID  Sequence                                          JobTitle  \
# 0           23         1                                           Manager
# 1           23         2                               Assisting customers
# 2          698         1                                  Advocate Bromenn
# 3          698         2  Customer Service, Patient contact, drawing blood
# 4          698         3              Customer Service, Suggestive selling
# ...        ...       ...                                               ...
# 11007  1471500         3                                   Cocktail Server
# 11008  1471500         4     ICS Associate /Overnight Stock/Truck Unloader
# 11009  1471500         5                                   Cocktail Server
# 11010  1471500         6                                            Server
# 11011  1471500         7                                            Server
#
#        JobCategoryID                                        CV_JobTitle
# 0                  0                        Manager Assisting customers
# 1                 30                        Manager Assisting customers
# 2                 88  Advocate Bromenn Customer Service, Patient con...
# 3                135  Advocate Bromenn Customer Service, Patient con...
# 4                  1  Advocate Bromenn Customer Service, Patient con...
# ...              ...                                                ...
# 11007             91  Stocker Cocktail Server ICS Associate /Overnig...
# 11008            136  Stocker Cocktail Server ICS Associate /Overnig...
# 11009             91  Stocker Cocktail Server ICS Associate /Overnig...
# 11010             91  Stocker Cocktail Server ICS Associate /Overnig...
# 11011             91  Stocker Cocktail Server ICS Associate /Overnig...
#
# [11012 rows x 5 columns]

# %%
df_users_history.loc[1,"JobCategoryID"]
# Out:
# 30

# %%
liste=[]
j=df_users_history.loc[0,"UserID"]
count=0
for i in df_users_history.UserID.values :
    #print(df_users_history.loc[count,"JobCategoryID"])
    if (i!=j):
        liste=[]
    liste.append(df_users_history.loc[count,"JobCategoryID"])
    df_users_history.loc[count,"liste_jobs"]=str(liste)
    count+=1
    j=i
    

    #print(liste)
df_users_history
# Out:
#         UserID  Sequence                                          JobTitle  \
# 0           23         1                                           Manager
# 1           23         2                               Assisting customers
# 2          698         1                                  Advocate Bromenn
# 3          698         2  Customer Service, Patient contact, drawing blood
# 4          698         3              Customer Service, Suggestive selling
# ...        ...       ...                                               ...
# 11007  1471500         3                                   Cocktail Server
# 11008  1471500         4     ICS Associate /Overnight Stock/Truck Unloader
# 11009  1471500         5                                   Cocktail Server
# 11010  1471500         6                                            Server
# 11011  1471500         7                                            Server
#
#        JobCategoryID                                        CV_JobTitle  \
# 0                  0                        Manager Assisting customers
# 1                 30                        Manager Assisting customers
# 2                 88  Advocate Bromenn Customer Service, Patient con...
# 3                135  Advocate Bromenn Customer Service, Patient con...
# 4                  1  Advocate Bromenn Customer Service, Patient con...
# ...              ...                                                ...
# 11007             91  Stocker Cocktail Server ICS Associate /Overnig...
# 11008            136  Stocker Cocktail Server ICS Associate /Overnig...
# 11009             91  Stocker Cocktail Server ICS Associate /Overnig...
# 11010             91  Stocker Cocktail Server ICS Associate /Overnig...
# 11011             91  Stocker Cocktail Server ICS Associate /Overnig...
#
#                      liste_jobs
# 0                           [0]
# 1                       [0, 30]
# 2                          [88]
# 3                     [88, 135]
# 4                  [88, 135, 1]
# ...                         ...
# 11007                   [0, 91]
# 11008              [0, 91, 136]
# 11009          [0, 91, 136, 91]
# 11010      [0, 91, 136, 91, 91]
# 11011  [0, 91, 136, 91, 91, 91]
#
# [11012 rows x 6 columns]

# %%
df_users_history["CV_JobTitle"]=df_users_history["CV_JobTitle"].apply(lambda x: nettoyage_texte(x))

# %% [markdown]
# Ce dataset contient les historiques des chercheurs d'emplois.

# %%
len(df_users_history.JobCategoryID.unique())
# Out:
# 197

# %%
df_users_history.Sequence.value_counts().sort_index()
# Out:
# 1     2420
# 2     2290
# 3     2053
# 4     1584
# 5     1060
# 6      697
# 7      397
# 8      256
# 9      157
# 10      90
# 11       5
# 12       2
# 13       1
# Name: Sequence, dtype: int64

# %%
print(len(df_users_history.UserID.unique()) )
print(len(df_users_history.UserID.unique()) - 77 +277)
print(2337)
# Out:
# 2509
# 2709
# 2337

# %% [markdown]
# ### df_test_users

# %%
df_test_users=pd.read_csv("test_users.csv")
print(df_test_users.shape)
df_test_users.TotalYearsExperience=pd.to_numeric(df_test_users.TotalYearsExperience)
df_test_users.head()
# Out:
# (277, 14)
#    UserID             City State Country  ZipCode  DegreeType          Major  \
# 0   12924          Chicago    IL      US    60628  Bachelor's            NaN
# 1   18947          Chicago    IL      US    60647        None            NaN
# 2   20976  Rolling Meadows    IL      US    60008    Master's            NaN
# 3   21412          Chicago    IL      US    60649        None  Basic Studies
# 4   40564             Zion    IL      US    60099        None            NaN
#
#         GraduationDate  WorkHistoryCount  TotalYearsExperience  \
# 0  2005-05-01 00:00:00                 4                   9.0
# 1                  NaN                 6                  22.0
# 2                  NaN                 5                   6.0
# 3  2007-01-01 00:00:00                 5                   5.0
# 4                  NaN                 6                   5.0
#
#   CurrentlyEmployed ManagedOthers  ManagedHowMany  MajorCategoryID
# 0               Yes            No               0              NaN
# 1               Yes            No               0              NaN
# 2                No           Yes               6              NaN
# 3               Yes            No               0              NaN
# 4               NaN            No               0              NaN

# %% [markdown]
# Cette table contient nos chercheurs d'emplois test. On en a 277.

# %% [markdown]
# Verifions que sur les utilisateurs du jeu de test ont tous donné des feedbacks.

# %%
UserID_test=list(df_test_users.UserID.unique())
UserID_train=list(df_users.UserID.unique())
UserID_feedback=list(df_feedbacks.UserID.unique())
UserID_history=list(df_users_history.UserID.unique())

# %%
len(UserID_train)
# Out:
# 2337

# %%
len(list(set(UserID_train).intersection(UserID_feedback)))
# Out:
# 1861

# %%
list(set(UserID_test).intersection(UserID_feedback))
# Out:
# []

# %% [markdown]
# Aucun des chercheur d'emploi du test set a donné un feedback.

# %%
list(set(UserID_test).intersection(UserID_train))
# Out:
# []

# %%
len(list(set(UserID_test).intersection(UserID_history)))
# Out:
# 263

# %%
len(UserID_test)
# Out:
# 277

# %% [markdown]
# ### Nettoyage

# %% [markdown]
# Dans la table test, on va sciendé les individus ayant de l'expérience ou pas.

# %%
df_test_users.TotalYearsExperience.value_counts()
# Out:
# 5.0     25
# 11.0    23
# 6.0     22
# 4.0     18
# 7.0     18
# 10.0    16
# 3.0     15
# 8.0     13
# 12.0    13
# 14.0    12
# 13.0    10
# 9.0     10
# 15.0     8
# 2.0      8
# 16.0     6
# 1.0      6
# 19.0     5
# 22.0     5
# 25.0     4
# 18.0     4
# 20.0     3
# 23.0     3
# 17.0     3
# 24.0     2
# 35.0     2
# 27.0     2
# 46.0     1
# 29.0     1
# 31.0     1
# 30.0     1
# 33.0     1
# 38.0     1
# 37.0     1
# 0.0      1
# Name: TotalYearsExperience, dtype: int64

# %% [markdown]
# On va créer la table de recommendation pour le jeu test.

# %%
len(list(df_test_users.UserID))
# Out:
# 277

# %%
liste_0=[0]*df_test_users.shape[0]

d = {'UserID': list(df_test_users.UserID), 'recommendation_1': liste_0,'recommendation_2': liste_0,'recommendation_3': liste_0,'recommendation_4': liste_0}
df_test_recommendation = pd.DataFrame(data=d)
df_test_recommendation
# Out:
#       UserID  recommendation_1  recommendation_2  recommendation_3  \
# 0      12924                 0                 0                 0
# 1      18947                 0                 0                 0
# 2      20976                 0                 0                 0
# 3      21412                 0                 0                 0
# 4      40564                 0                 0                 0
# ..       ...               ...               ...               ...
# 272  1454754                 0                 0                 0
# 273  1458384                 0                 0                 0
# 274  1458917                 0                 0                 0
# 275  1466313                 0                 0                 0
# 276  1471500                 0                 0                 0
#
#      recommendation_4
# 0                   0
# 1                   0
# 2                   0
# 3                   0
# 4                   0
# ..                ...
# 272                 0
# 273                 0
# 274                 0
# 275                 0
# 276                 0
#
# [277 rows x 5 columns]

# %%
# On va créer nos tables pour les individus et les jobs  restreint avec les features de modélisation

# %% [markdown]
# ### Analyse

# %% [markdown]
# # <center> Piste de modélisation </center>

# %% [markdown]
# ### Hypothèses

# %% [markdown]
# 1/ En moyenne, l'étude StepStone observe qu'il faut envoyer 20 CV pour décrocher un job et postueler sur 5 sites  et  80 % des candidats utilisent au minimum 5 sites différents pour postuler. 20/5=4, nous allons donc proposer 4 offres d'emploi à nos chercheurs d'emplois car cela serait le nombre optimal.

# %% [markdown]
# 2/ Pour faciliter notre problème, on va considérer que nos offre d'emplois ont une capacité d'embauche supérieur à 1. C'est à dire que même si un chercheur d'emploi y est engagé alors un autre peut y candidater.

# %% [markdown]
# 3/ On considérera que les individus n'ayant pas d'historiques via leur CV sont soit des personnes en insertion professionnels soit des personnes ayant connu une longue période de chomage.

# %%
20/5
# Out:
# 4.0

# %%
4291/2337
# Out:
# 1.836114676936243

# %% [markdown]
# On partire du principe que notre

# %% [markdown]
# ### Etape 0 :  Recommendations non personnalisées pour les individus sans expérience déclarée.

# %% [markdown]
# On sépare les individus qui ont communiqués leurs expériences passées avec ceux qui ne l'ont pas fait. On supposera que les individus n'ayant pas communiqué leurs expériences passées sont des outliers sur le marché du travail. Des personnes en insertion professionnelle (étudiants, chomeurs longue durées) ou bien des gens qui ont un CV non crédible.

# %%
UserID_test=list(df_test_users.UserID.unique())
UserID_train=list(df_users.UserID.unique())
UserID_feedback=list(df_feedbacks.UserID.unique())
UserID_history=list(df_users_history.UserID.unique())

# %%
df_test_users
# Out:
#       UserID             City State Country  ZipCode  DegreeType  \
# 0      12924          Chicago    IL      US    60628  Bachelor's
# 1      18947          Chicago    IL      US    60647        None
# 2      20976  Rolling Meadows    IL      US    60008    Master's
# 3      21412          Chicago    IL      US    60649        None
# 4      40564             Zion    IL      US    60099        None
# ..       ...              ...   ...     ...      ...         ...
# 272  1454754      Des Plaines    IL      US    60016  Bachelor's
# 273  1458384          Chicago    IL      US    60630        None
# 274  1458917           Aurora    IL      US    60502  Bachelor's
# 275  1466313         Glenview    IL      US    60026    Master's
# 276  1471500       Crest Hill    IL      US    60403        None
#
#                              Major       GraduationDate  WorkHistoryCount  \
# 0                              NaN  2005-05-01 00:00:00                 4
# 1                              NaN                  NaN                 6
# 2                              NaN                  NaN                 5
# 3                    Basic Studies  2007-01-01 00:00:00                 5
# 4                              NaN                  NaN                 6
# ..                             ...                  ...               ...
# 272          Accounting & Auditing                  NaN                 7
# 273                            NaN                  NaN                10
# 274  Telecommunications Management  2001-10-01 00:00:00                 6
# 275           Marketing/Management                  NaN                 8
# 276                            NaN                  NaN                 7
#
#      TotalYearsExperience CurrentlyEmployed ManagedOthers  ManagedHowMany  \
# 0                     9.0               Yes            No               0
# 1                    22.0               Yes            No               0
# 2                     6.0                No           Yes               6
# 3                     5.0               Yes            No               0
# 4                     5.0               NaN            No               0
# ..                    ...               ...           ...             ...
# 272                  27.0                No            No               0
# 273                  23.0               NaN            No               0
# 274                   6.0               NaN            No               0
# 275                  22.0               Yes            No               0
# 276                   9.0                No            No               0
#
#      MajorCategoryID
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 4                NaN
# ..               ...
# 272              NaN
# 273              NaN
# 274              NaN
# 275              NaN
# 276              NaN
#
# [277 rows x 14 columns]

# %%
len(UserID_test)
# Out:
# 277

# %%
liste_test_with_history=list(set(UserID_test).intersection(UserID_history))

# %%
df_test_recherche=df_test_users[df_test_users['UserID'].isin(liste_test_with_history)]
df_test_insertion= df_test_users[~df_test_users['UserID'].isin(liste_test_with_history)]
df_test_insertion
# Out:
#       UserID        City State Country  ZipCode   DegreeType  \
# 5      42836     Chicago    IL      US    60628         None
# 22    138347    Hometown    IL      US    60456         None
# 89    480980     Chicago    IL      US    60617         None
# 99    539448  Belleville    IL      US    62221         None
# 114   647688     Chicago    IL      US    60617         None
# 120   665250     Chicago    IL      US    60619         None
# 161   909842     Chicago    IL      US    60628         None
# 168   932306     Chicago    IL      US    60636  High School
# 183  1022450     Chicago    IL      US    60647   Bachelor's
# 195  1069475     Chicago    IL      US    60620         None
# 199  1087050       Alton    IL      US    62002   Bachelor's
# 221  1179202      Gurnee    IL      US    60031         None
# 265  1401559     Chicago    IL      US    60652  Associate's
# 271  1451904     Chicago    IL      US    60643  High School
#
#                                     Major       GraduationDate  \
# 5                                     NaN                  NaN
# 22                                    NaN                  NaN
# 89                                    NaN                  NaN
# 99                                Biology  2012-04-01 00:00:00
# 114                                   NaN                  NaN
# 120                                   NaN                  NaN
# 161                                   NaN                  NaN
# 168                        Not Applicable  2008-01-01 00:00:00
# 183  Communicative Sciences and Disorders  2008-05-01 00:00:00
# 195                                   NaN                  NaN
# 199                           BA business  2013-06-01 00:00:00
# 221                                   NaN                  NaN
# 265         Health Information Technology  2011-01-01 00:00:00
# 271                Mechanical Engineering  2012-05-01 00:00:00
#
#      WorkHistoryCount  TotalYearsExperience CurrentlyEmployed ManagedOthers  \
# 5                   0                   NaN               NaN            No
# 22                  0                   NaN               NaN            No
# 89                  1                   4.0                No            No
# 99                  0                   NaN                No            No
# 114                 0                   NaN               NaN            No
# 120                 0                   NaN                No            No
# 161                 0                   NaN               NaN            No
# 168                 0                   NaN                No            No
# 183                 0                   NaN                No           Yes
# 195                 0                   NaN                No            No
# 199                 0                   NaN                No            No
# 221                 0                   NaN               NaN            No
# 265                 0                   NaN                No            No
# 271                 0                   NaN                No           Yes
#
#      ManagedHowMany  MajorCategoryID
# 5                 0              NaN
# 22                0              NaN
# 89                0              NaN
# 99                0              0.0
# 114               0              NaN
# 120               0              NaN
# 161               0              NaN
# 168               0              0.0
# 183               3              NaN
# 195               0              NaN
# 199               0              NaN
# 221               0              NaN
# 265               0            134.0
# 271              15            148.0

# %% [markdown]
# le numero 539448 est un étudiant en insertion professionnelle car il sa date d'obtention du diplome est proche de celle des disponibilité pour les jobs.

# %%
outliers=list(df_test_insertion.UserID)
outliers
# Out:
# [42836,
#  138347,
#  480980,
#  539448,
#  647688,
#  665250,
#  909842,
#  932306,
#  1022450,
#  1069475,
#  1087050,
#  1179202,
#  1401559,
#  1451904]

# %%
#liste des jobs populaires, regardées plus que 75% des autres offres.
#popular_job=df_feedbacks.JobID.value_counts().to_frame()
#liste_popular_job=list(popular_job[popular_job["JobID"]>8].index)
liste_popular_job
# Out:
# [1050985,
#  896947,
#  837446,
#  386591,
#  67025,
#  749238,
#  871285,
#  489323,
#  209212,
#  83739,
#  314766,
#  615722,
#  23302,
#  8315,
#  597857,
#  788041,
#  1113991,
#  683930,
#  550180,
#  110541,
#  280705,
#  458789,
#  681893,
#  26102,
#  595723,
#  896220,
#  1050685,
#  300786,
#  1104317,
#  158490,
#  1032351,
#  384121,
#  852994,
#  300778,
#  805616,
#  434309,
#  643234,
#  864447,
#  95835,
#  240127,
#  900555,
#  502883,
#  636190,
#  568000,
#  697788,
#  212537,
#  643233,
#  886039,
#  156625,
#  879350,
#  863547,
#  535582,
#  812538,
#  1053272,
#  822884,
#  969928,
#  14391,
#  381975,
#  95535,
#  171400,
#  1009302,
#  182525,
#  299233,
#  1081649,
#  554639,
#  46841,
#  382487,
#  268576,
#  848283,
#  39412,
#  323711,
#  1051415,
#  758183,
#  749790,
#  512697,
#  377336,
#  537997,
#  691506,
#  845007,
#  483050,
#  572536,
#  961414,
#  744000,
#  811952,
#  970144,
#  315453,
#  511755,
#  1009301,
#  59597,
#  780502,
#  861085,
#  883740,
#  203025,
#  580945,
#  578522,
#  44890,
#  23341,
#  223139,
#  326864,
#  260701,
#  1069767,
#  734022,
#  867182,
#  205628,
#  647270,
#  811951,
#  1061320,
#  535043,
#  878077,
#  1053273,
#  600837,
#  134532,
#  780423,
#  804823,
#  1090011,
#  267607,
#  1055630,
#  157678,
#  796649,
#  173112,
#  103650,
#  109963,
#  980870,
#  928489,
#  638160,
#  1061316,
#  960305,
#  1069294,
#  1014730,
#  617464,
#  695986,
#  933846,
#  801550,
#  144385,
#  1060652,
#  523372,
#  342297,
#  403850,
#  900554,
#  16758,
#  538010,
#  616943,
#  779489,
#  1074763,
#  775818,
#  75390,
#  854431,
#  865009,
#  322990,
#  346317,
#  634454,
#  161507,
#  35594,
#  300800,
#  1091855,
#  315685,
#  5236,
#  300761,
#  339034,
#  264069,
#  311881,
#  929706,
#  580319,
#  950500,
#  158541,
#  141740,
#  850483,
#  314424,
#  450906,
#  820524,
#  388692,
#  452135,
#  535053,
#  1050684,
#  58070,
#  579280,
#  634530,
#  1102366,
#  273429,
#  328180,
#  966795,
#  364686,
#  209257,
#  938722,
#  274142,
#  278240,
#  187303,
#  520424,
#  395981,
#  570769,
#  584318,
#  467281,
#  512240,
#  15326,
#  798380,
#  242406,
#  95833,
#  864086,
#  523371,
#  624004,
#  223451,
#  164236,
#  47341,
#  823574,
#  597887,
#  576740,
#  1013763,
#  876956,
#  391094,
#  908126,
#  561145,
#  223426,
#  28608,
#  1049580,
#  843781,
#  634714,
#  35995,
#  823590,
#  878767,
#  384119,
#  640630,
#  782309,
#  496206,
#  997571,
#  80922,
#  801487,
#  578118,
#  1267,
#  1053268,
#  38358,
#  806226,
#  899434,
#  773851,
#  363275,
#  509449,
#  338414,
#  739705,
#  264187,
#  40762,
#  617350,
#  928036,
#  600833,
#  34766,
#  66956,
#  567690,
#  137014,
#  1109223,
#  572126,
#  584719,
#  940397,
#  775312,
#  175495,
#  435087,
#  212429,
#  1113149,
#  874607,
#  16467,
#  97771,
#  1038058,
#  787822,
#  845269,
#  334105,
#  863240,
#  803468,
#  448427,
#  1011686,
#  852315,
#  628316,
#  174030,
#  195613,
#  325624,
#  483047,
#  458782,
#  739617,
#  319884,
#  830646,
#  879825,
#  101184,
#  182641,
#  22663,
#  928144,
#  966439,
#  316849,
#  782690,
#  702606,
#  173609,
#  700645,
#  380891,
#  822219,
#  1020516,
#  871852,
#  278367,
#  327530,
#  270342,
#  628593,
#  285380,
#  51962,
#  523635,
#  780267,
#  583179,
#  1251,
#  281608,
#  879572,
#  791768,
#  587287,
#  868403,
#  280989,
#  279238,
#  357397,
#  925554,
#  223110,
#  773536,
#  1115326,
#  597367,
#  160501,
#  234034,
#  223425,
#  823579,
#  498767,
#  35120,
#  300548,
#  655858,
#  596302,
#  566702,
#  1041410,
#  616963,
#  382173,
#  823598,
#  876955,
#  845970,
#  773738,
#  430778,
#  541723,
#  586145,
#  1102646,
#  613940,
#  617304,
#  268638,
#  523402,
#  1061328,
#  1106263,
#  203371,
#  461997,
#  408498,
#  600866,
#  925327,
#  1041209,
#  511368,
#  644540,
#  17046,
#  478910,
#  1010954,
#  769390,
#  55854,
#  165417,
#  997569,
#  882702,
#  933568,
#  280140,
#  988035,
#  95831,
#  576739,
#  365171,
#  262059,
#  600875,
#  867887,
#  915019,
#  222326,
#  925011,
#  996853,
#  615640,
#  396319,
#  900920,
#  955618,
#  608468,
#  1097743,
#  253974,
#  111726,
#  14122,
#  632363,
#  685006,
#  803631,
#  296936,
#  495165,
#  523376,
#  512698,
#  369009,
#  515304,
#  188685,
#  314264,
#  1065428,
#  278110,
#  846984,
#  925818,
#  925936,
#  577653,
#  217461,
#  195829,
#  600817,
#  357303,
#  364685,
#  110393,
#  196718,
#  577030,
#  908550,
#  42606,
#  870015,
#  661261,
#  631961,
#  852699,
#  355050,
#  1057176,
#  880321,
#  823576,
#  869166,
#  645368,
#  640764,
#  332106,
#  602534,
#  777461,
#  835542,
#  184085,
#  668916,
#  1090455,
#  1014926,
#  980543,
#  152574,
#  1032345,
#  212098,
#  633100,
#  511415,
#  201925,
#  212091,
#  284608,
#  822285,
#  2250,
#  182637,
#  946711,
#  1106656,
#  701122,
#  369295,
#  14295,
#  381976,
#  814350,
#  407329,
#  277818,
#  853450,
#  1103804,
#  852997,
#  792230,
#  806565,
#  1097020,
#  299660,
#  851675,
#  95524,
#  858226,
#  573231,
#  1046820,
#  273444,
#  286458,
#  1079189,
#  108822,
#  196129,
#  730545,
#  263478,
#  752326,
#  187060,
#  1019160,
#  71783,
#  261215,
#  910645,
#  561089,
#  1105755,
#  381166,
#  270196,
#  833857,
#  467154,
#  578521,
#  1030466,
#  1053269,
#  876782,
#  491268,
#  898791,
#  161267,
#  370817,
#  254388,
#  98160,
#  779675,
#  136804,
#  899122,
#  631976,
#  599100,
#  301286,
#  469574,
#  317359,
#  152269,
#  878359,
#  223125,
#  359815,
#  1091837,
#  566634,
#  182661,
#  945296,
#  497410,
#  600857,
#  150522,
#  209219,
#  846417,
#  386659,
#  564170,
#  1104401,
#  459370,
#  339192,
#  653357,
#  896847,
#  499497,
#  1103799,
#  178588,
#  363540,
#  219842,
#  338168,
#  492219,
#  682035,
#  996337,
#  475879,
#  675938,
#  813951,
#  877544,
#  223435,
#  884978,
#  1041808,
#  995576,
#  366852,
#  833902,
#  565900,
#  966436,
#  1053972,
#  878076,
#  1099844,
#  965506,
#  1025818,
#  864901,
#  339499,
#  601647,
#  374160,
#  616336,
#  251635,
#  809710,
#  448393,
#  336213,
#  842221,
#  764269,
#  963081,
#  748650,
#  1098275,
#  388602,
#  70070,
#  396768,
#  278986,
#  779676,
#  830713,
#  805620,
#  815547,
#  142909,
#  138024,
#  791808,
#  224360,
#  583341,
#  23307,
#  346871,
#  674938,
#  507622,
#  570430,
#  895420,
#  875624,
#  408858,
#  250004,
#  361813,
#  92251,
#  449879,
#  627019,
#  204810,
#  471742,
#  651880,
#  1096893,
#  343291,
#  673026,
#  923380,
#  523364,
#  796014,
#  13421,
#  1030813,
#  11180,
#  243870,
#  144096,
#  86585,
#  709250,
#  611417,
#  1034767,
#  17075,
#  1003005,
#  1055917,
#  768189,
#  15631,
#  312132,
#  1069062,
#  315572,
#  1090888,
#  707983,
#  642981,
#  7404,
#  994856,
#  746080,
#  1061305,
#  281307,
#  435131,
#  282619,
#  979457,
#  987728,
#  823570,
#  576068,
#  1025827,
#  877438,
#  798715,
#  474805,
#  962983,
#  902230,
#  198214,
#  373544,
#  92355,
#  998137,
#  899622,
#  682113,
#  1090566,
#  782694,
#  1022610,
#  466733,
#  840492,
#  823596,
#  512183,
#  242052,
#  305442,
#  300775,
#  491764,
#  320507,
#  908217,
#  639981,
#  774712,
#  1015885,
#  223135,
#  1018947,
#  10702,
#  285037,
#  108408,
#  445423,
#  458823,
#  64527,
#  823947,
#  1030518,
#  377337,
#  1105452,
#  653024,
#  544860,
#  137261,
#  663502,
#  1030027,
#  1059050,
#  201624,
#  916975,
#  218288,
#  289801,
#  615724,
#  517805,
#  340893,
#  2885,
#  335353,
#  300789,
#  457789,
#  599092,
#  780269,
#  492445,
#  761360,
#  581881,
#  624165,
#  224271,
#  912470,
#  852144,
#  599143,
#  559537,
#  61869,
#  278002,
#  898653,
#  334032,
#  631967,
#  1017290,
#  811380,
#  775909,
#  323509,
#  953882,
#  164268,
#  610864,
#  274447,
#  535580,
#  819516,
#  705747,
#  182628,
#  784644,
#  764107,
#  212560,
#  966438,
#  775915,
#  223264,
#  568536,
#  482481,
#  54750,
#  639047,
#  382108,
#  720391,
#  300776,
#  79255,
#  300823,
#  1053762,
#  1047982,
#  142272,
#  429844,
#  744827,
#  1026537,
#  451696,
#  658158,
#  638164,
#  749232,
#  531680,
#  156776,
#  203169,
#  908371,
#  161007,
#  162697,
#  253658,
#  1081988,
#  344595,
#  77059,
#  1083227,
#  149500,
#  505479,
#  954034,
#  1068503,
#  394502,
#  512150,
#  22371,
#  206198,
#  153190,
#  925234,
#  941655,
#  600813,
#  911109,
#  764362,
#  1041748,
#  467221,
#  885404,
#  188620,
#  156866,
#  267804,
#  765193,
#  782,
#  904839,
#  377039,
#  62255,
#  317134,
#  1042854,
#  57807,
#  851536,
#  1575,
#  34079,
#  265547,
#  130558,
#  821748,
#  144397,
#  1027158,
#  97589,
#  773292,
#  877936,
#  775549,
#  641281]

# %%
df_test_recommendation
# Out:
#       UserID  recommendation_1  recommendation_2  recommendation_3  \
# 0      12924                 0                 0                 0
# 1      18947                 0                 0                 0
# 2      20976                 0                 0                 0
# 3      21412                 0                 0                 0
# 4      40564                 0                 0                 0
# ..       ...               ...               ...               ...
# 272  1454754                 0                 0                 0
# 273  1458384                 0                 0                 0
# 274  1458917                 0                 0                 0
# 275  1466313                 0                 0                 0
# 276  1471500                 0                 0                 0
#
#      recommendation_4
# 0                   0
# 1                   0
# 2                   0
# 3                   0
# 4                   0
# ..                ...
# 272                 0
# 273                 0
# 274                 0
# 275                 0
# 276                 0
#
# [277 rows x 5 columns]

# %%
outliers
# Out:
# [42836,
#  138347,
#  480980,
#  539448,
#  647688,
#  665250,
#  909842,
#  932306,
#  1022450,
#  1069475,
#  1087050,
#  1179202,
#  1401559,
#  1451904]

# %%
random.seed(10)
df_test_recommendation["recommendation_1"]






for i in df_test_recommendation.values:
    if i[0] in outliers :
        i[1]=random.choice(liste_popular_job)
        i[2]=random.choice(liste_popular_job)
        i[3]=random.choice(liste_popular_job)
        i[4]=random.choice(liste_popular_job)
        

print(df_test_recommendation.recommendation_3.value_counts())
df_test_recommendation.head()
# Out:
# 0          263
# 212537       1
# 457789       1
# 218288       1
# 223426       1
# 701122       1
# 201925       1
# 608468       1
# 779489       1
# 782          1
# 1019160      1
# 137014       1
# 182661       1
# 403850       1
# 815547       1
# Name: recommendation_3, dtype: int64
#    UserID  recommendation_1  recommendation_2  recommendation_3  \
# 0   12924                 0                 0                 0
# 1   18947                 0                 0                 0
# 2   20976                 0                 0                 0
# 3   21412                 0                 0                 0
# 4   40564                 0                 0                 0
#
#    recommendation_4
# 0                 0
# 1                 0
# 2                 0
# 3                 0
# 4                 0

# %% [markdown]
# ### Etape 1 : Vision "entreprise", concordance des profils avec les offres d'emploi

# %% [markdown]
# L'objectif ici est de vérifier la concordance des offres des entreprises avec les profils des candidats.

# %% [markdown]
# ##### Recommendations

# %%
def recommendation_CV(test) :
    liste_job=list(df_jobs.Title)
    liste_job.append(test)
    #liste_job[-1]
    vectorizer = TfidfVectorizer()
    vectors = vectorizer.fit_transform(liste_job)
    feature_names = vectorizer.get_feature_names()
    dense = vectors.todense()
    denselist = dense.tolist()
    df = pd.DataFrame(denselist, columns=feature_names)
    cosine_sim = cosine_similarity(df, df)
    d = {'cosinus': list(cosine_sim[-1]), 'offres':list(range(cosine_sim.shape[1]))}
    df = pd.DataFrame(data=d)
    df=df.sort_values(by=['cosinus'])
    recommendation_1=df.index[-2]
    #print(df_jobs.Title[recommendation_1])
    recommendation_2=df.index[-3]
    #print(df_jobs.Title[recommendation_2])
    recommendation_3=df.index[-4]
    #print(df_jobs.Title[recommendation_3])
    recommendation_4=df.index[-5]
    #print(df_jobs.Title[recommendation_4])
    recommendation_5=df.index[-6]
    #print(df_jobs.Title[recommendation_5])
    recommendation_6=df.index[-7]
    #print(df_jobs.Title[recommendation_6])

    
  
    recommendation_jobs=[recommendation_1,recommendation_2,recommendation_3,recommendation_4,recommendation_5,recommendation_6]
    recommendation_jobs_probs=[  round(df.cosinus.values[-2],3), round(df.cosinus.values[-3],3),round(df.cosinus.values[-4],3),round(df.cosinus.values[-5],3),round(df.cosinus.values[-6],3),round(df.cosinus.values[-7],3)]
    
    d_final = {'cosinus': recommendation_jobs_probs, 'offres':recommendation_jobs}
    df_final = pd.DataFrame(data=d_final)
    
    return(df_final)

# %% [markdown]
# Testons notre  modèle avec un exemple.

# %%
test=df_users_history["CV_JobTitle"][4893]
print(test)
# Out:
# instructor substitute teacher teacher preschool 3rd grade 5th grade long term substitute teacher student teacher 2nd grade

# %%
resultat=recommendation_CV(test)
resultat
# Out:
#    cosinus  offres
# 0    0.381    2288
# 1    0.345     463
# 2    0.328    2575
# 3    0.285    1844
# 4    0.284    3478
# 5    0.247    4051

# %%
for i in list(resultat.offres.values[:]) :
    print(i)
    print(df_jobs.Title[i])
# Out:
# 2288
# teacher infant preschool program
# 463
# kindergarden lead teacher
# 2575
# teacher early childhood education preschool
# 1844
# early childhood teacher aurora
# 3478
# lead teacher kiddie academy
# 4051
# exciting kindergarten teacher opportunity bartlett

# %%
df_jobs.head()
# Out:
#    JobID                           Title  \
# 0     75        administrative assistant
# 1    505                        lab tech
# 2    764           travel seasonal staff
# 3    766  marketing social medium intern
# 4    781                   printing sale
#
#                                          Description  \
# 0  The Administrative Assistant must be reliable ...
# 1  S. Florida Medical Device Co. seeks QC Lab Tec...
# 2  <p>Travel-Seasonal Staff </p> <p> CB331736 Ros...
# 3  <p>Marketing Rep </p> <p> CB326227 Chicago </p...
# 4  <p>Printing Sales Experienced, outside sales w...
#
#                                         Requirements           City State  \
# 0  Please refer to the Job Description to view th...        Houston    TX
# 1  General knowledge of scientific or clinical la...     Plantation    FL
# 2  Please refer to the Job Description to view th...    Des Plaines    IL
# 3  Please refer to the Job Description to view th...        Chicago    IL
# 4  Please refer to the Job Description to view th...  Schiller Park    IL
#
#   Country     Zip5                StartDate              EndDate  \
# 0      US  77036.0  2012-03-30 01:23:57.737  2012-04-29 23:59:59
# 1      US  33313.0  2012-03-23 04:48:17.063  2012-04-22 23:59:59
# 2      US  60018.0  2012-03-18 05:19:04.863  2012-04-17 23:59:59
# 3      US  60606.0   2012-03-22 10:33:46.89  2012-04-21 23:59:59
# 4      US  60176.0  2012-04-01 01:16:40.797  2012-04-30 23:59:59
#
#    JobCategoryID
# 0             20
# 1            137
# 2             59
# 3            141
# 4              4

# %%
count=0
for i in resultat.offres.values:
    print(i)
    print(df_jobs.loc[i,"JobCategoryID"])
    resultat.loc[count,"JobCategoryID"]=df_jobs.loc[i,"JobCategoryID"]
    count+=1
# Out:
# 2288
# 0
# 463
# 40
# 2575
# 131
# 1844
# 0
# 3478
# 19
# 4051
# 40

# %%
resultat
# Out:
#    cosinus  offres  JobCategoryID
# 0    0.381    2288            0.0
# 1    0.345     463           40.0
# 2    0.328    2575          131.0
# 3    0.285    1844            0.0
# 4    0.284    3478           19.0
# 5    0.247    4051           40.0

# %% [markdown]
# #### Ajout de features

# %% [markdown]
# Catégorie du travail

# %%
resultat
# Out:
#    cosinus  offres  JobCategoryID
# 0    0.381    2288            0.0
# 1    0.345     463           40.0
# 2    0.328    2575          131.0
# 3    0.285    1844            0.0
# 4    0.284    3478           19.0
# 5    0.247    4051           40.0

# %%
#df_users_history_max=df_users_history_max.reset_index()
#df_users_history_max

# %%
#test=df_users_history_max.values
#test[-1]

# %%
df_jobs.JobCategoryID
# Out:
# 0        20
# 1       137
# 2        59
# 3       141
# 4         4
#        ...
# 4286     14
# 4287    178
# 4288    178
# 4289    178
# 4290     77
# Name: JobCategoryID, Length: 4291, dtype: int64

# %% [markdown]
# Prérequis management

# %% [markdown]
# ### Etape 2 :  Vision "employé", concordance des offres d'emploi avec les envies des demandeurs d'emploi.

# %% [markdown]
# La conclusion d'un contrat est un accord bilatéral entre le salarié et l'employeur. C'est pourquoi nous allons recoefficienté nos features avec une régression logistique sur les feedbacks.

# %% [markdown]
# ### Table Final

# %%
df_test_recommendation
# Out:
#       UserID  recommendation_1  recommendation_2  recommendation_3  \
# 0      12924                 0                 0                 0
# 1      18947                 0                 0                 0
# 2      20976                 0                 0                 0
# 3      21412                 0                 0                 0
# 4      40564                 0                 0                 0
# ..       ...               ...               ...               ...
# 272  1454754                 0                 0                 0
# 273  1458384                 0                 0                 0
# 274  1458917                 0                 0                 0
# 275  1466313                 0                 0                 0
# 276  1471500                 0                 0                 0
#
#      recommendation_4
# 0                   0
# 1                   0
# 2                   0
# 3                   0
# 4                   0
# ..                ...
# 272                 0
# 273                 0
# 274                 0
# 275                 0
# 276                 0
#
# [277 rows x 5 columns]

# %%
test=df_users_history["CV_JobTitle"][4893]
print(test)
resultat=recommendation_CV(test)
resultat
# Out:
# instructor substitute teacher teacher preschool 3rd grade 5th grade long term substitute teacher student teacher 2nd grade
#    cosinus  offres
# 0    0.381    2288
# 1    0.345     463
# 2    0.328    2575
# 3    0.285    1844
# 4    0.284    3478
# 5    0.247    4051

# %%
df_users_history["CV_JobTitle"][1294]
# Out:
# 'accountant accountant accountant accountant general ledger accountant junior staff accountant'

# %%
#for i in df_test_recommendation.values:
#print(i[0])
resultat.offres.values[0]
df_test_recommendation.values
# Out:
# array([[  12924,       0,       0,       0,       0],
#        [  18947,       0,       0,       0,       0],
#        [  20976,       0,       0,       0,       0],
#        ...,
#        [1458917,       0,       0,       0,       0],
#        [1466313,       0,       0,       0,       0],
#        [1471500,       0,       0,       0,       0]])

# %%
df_users_history.index=df_users_history.loc[:,"UserID"]

# %%
history=df_users_history["CV_JobTitle"].drop_duplicates()
history[23]
#history.index=history.loc[:,"UserID"]
# Out:
# 'manager assisting customer'

# %%
history.values[1]
# Out:
# 'advocate bromenn customer service patient contact drawing blood customer service suggestive selling customer service retail'

# %%
history=df_users_history["CV_JobTitle"].drop_duplicates()
count=0

for i in df_test_recommendation.values:
    #print(i[0])
    if i[0] not in outliers :
        try:
            resultat=recommendation_CV(history[i[0]])
            i[1]=resultat.offres.values[0]
            i[2]=resultat.offres.values[1]
            i[3]=resultat.offres.values[2]
            i[4]=resultat.offres.values[3]
        except:
            count+=1

        
print(count,"erreurs")

df_test_recommendation.head()
# Out:
# 2 erreurs
#    UserID  recommendation_1  recommendation_2  recommendation_3  \
# 0   12924              1958              2802              4232
# 1   18947              4110              1544              3861
# 2   20976              1054              2720              3407
# 3   21412              2999              1405              2240
# 4   40564              4187              2172              2177
#
#    recommendation_4
# 0              2780
# 1               286
# 2              2386
# 3                33
# 4              2390

# %% [markdown]
# # Résultat

# %%
#test=df_users_history["CV_JobTitle"][4893]
#print(test)

df_test_recommendation.to_csv("Recommendation.csv",index=False)

# %%
end = time.time()
print("Le temps ecoulé :",end - start)
# Out:
# Le temps ecoulé : 596.3967068195343

# %% [markdown]
# ### Discussion sur les résultats

# %% [markdown]
# ### Limites

# %% [markdown]
# raisonnement par clusters pour le scoring :
#     - poids des caractéristiques du scoring :  fruitz intention peche change matching
#     - contrat de maintenance : youtube et les boucles infinies en recommendation

# %% [markdown]
# ### Sources
#
# Les sources utilisées pour concevoir ce notebook sont :
# - https://github.com/jalajthanaki/Job_recommendation_engine/blob/master/Job_recommendation_engine.ipynb
# - https://app.datacamp.com/learn/courses/building-recommendation-engines-in-python
# - https://www.jobspikr.com/blog/job-matching-algorithms/
